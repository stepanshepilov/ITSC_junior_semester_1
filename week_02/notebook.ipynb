# %%
a = 5
b = "string"
c = 10.6
d = 4 + 5j

# %%
e = [1, 2, 3, "string", [5, 6, 7]]

for item in e:
    print(item)
# Out:
# 1
# 2
# 3
# string
# [5, 6, 7]

# %%
e[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 e[10]
#
# IndexError: list index out of range

# %%
e.append(4)
e
# Out:
# [1, 2, 3, 'string', [5, 6, 7], 4]

# %%
e[0] = 100

# %%
e
# Out:
# [100, 2, 3, 'string', [5, 6, 7], 4]

# %%
f = (1, 2, 3)
f[0] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 f = (1, 2, 3)
# ----> 2 f[0] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
g = {1, 1, 2, 3, 3, 4}
g
# Out:
# {1, 2, 3, 4}

# %%
h = set([1, 2, 2, 3])
h
# Out:
# {1, 2, 3}

# %%
j = {
    "dataset": ...,
    "model": ..., 
}

# %%
j["a"]
# Out:
# [1, 2, 3]

# %%
j.get("b", [])
# Out:
# []

# %%
string = "acbdefg"

for char in string:
    print(char)
# Out:
# a
# c
# b
# d
# e
# f
# g
